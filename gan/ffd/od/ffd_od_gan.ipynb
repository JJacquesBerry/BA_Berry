# %% [markdown]
# - neural network - audioData 2

# %%
import numpy as np
import tensorflow.keras as keras
import keras.layers as layers
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import soundfile as sf

# %% [markdown]
# Add path to util-functions

# %%
import sys
sys.path.append('D:/1. Studium/7. Semester/BA/Birdvoice/utils')

# %% [markdown]
# The Paths to the OD-databases

# %%
databasePathsParusMajor=['../../../dataPreprocessing/databases/od/ParusMajor/ParusMajorSongOD1.csv', '../../../dataPreprocessing/databases/od/ParusMajor/ParusMajorSongOD5.csv']
databasePathsTurdusMerula=['../../../dataPreprocessing/databases/od/TurdusMerula/TurdusMerulaSongOD5.csv']
databasePathsCorvusCorone=['../../../dataPreprocessing/databases/od/CorvusCorone/CorvusCoroneCallOD5.csv']

# %% [markdown]
# Load data from chosen path

# %%
sampleCount = 2000

x_train = pd.read_csv(databasePathsCorvusCorone[0], header=None, delimiter=',', index_col=None, nrows=sampleCount).to_numpy()
_, AUDIO_COLS = x_train.shape
print(x_train.shape)
# Out:
# (2000, 55125)

# %% [markdown]
# Generator

# %%
def buildGenerator():
    model = keras.models.Sequential()
    
    model.add(keras.layers.InputLayer(input_shape=(AUDIO_COLS)))
    
    model.add(keras.layers.Dense(256))

    model.add(keras.layers.Dense(512))

    model.add(keras.layers.Dense(1024))

    model.add(keras.layers.Dense(AUDIO_COLS, activation="tanh"))
              
    return model

# %% [markdown]
# Discriminator

# %%
def buildDiscriminator():
    model = keras.models.Sequential()
    
    model.add(keras.layers.InputLayer(AUDIO_COLS))
    
    model.add(keras.layers.Dense(512))
    
    model.add(keras.layers.Dense(256))

    model.add(keras.layers.Dense(1, activation="sigmoid"))

    return model

# %% [markdown]
# Train function

# %%
def train(iterations, batch_size=64):
    
    valid = np.ones(batch_size)
    generated = np.zeros(batch_size)
    
    for i in range(iterations):
        #select audios from data
        indices = np.random.randint(0, len(x_train), batch_size)
        audios = x_train[indices]
        
        #get fake audio from generator
        noise = np.random.normal(0,0.05, (batch_size, AUDIO_COLS))
        generated_audios = generator.predict(noise)
        
        # train discriminator with the "real" audios:
        d_loss_real = discriminator.train_on_batch(audios, valid,return_dict=True)
        d_loss_gen = discriminator.train_on_batch(generated_audios, generated, return_dict=True)
        
        print(f"Iteration: {i}")
        print(f"d_loss_real: {d_loss_real}")
        print(f"d_loss_gen: {d_loss_gen}")

        # train generator 
        noise = np.random.normal(0,0.05, (batch_size, AUDIO_COLS))
        g_loss = gan.train_on_batch(noise, valid)
        
        print(f"g_loss: {g_loss}")

# %% [markdown]
# Optimizer

# %%
optimiser = keras.optimizers.Adamax(0.001, 0.9)

# %% [markdown]
# Create the discriminator

# %%
discriminator = buildDiscriminator()
discriminator.compile(loss = "binary_crossentropy",
                      optimizer = optimiser,
                      metrics = "accuracy")

# %% [markdown]
# Create the generator

# %%
generator = buildGenerator()
discriminator.trainable = False # freeze weights of discriminator
gan = keras.models.Sequential( [generator, discriminator] )
gan.compile(loss="binary_crossentropy",
           optimizer = optimiser,
           metrics = "accuracy")

# %% [markdown]
# Run the training:

# %%
ITERATIONS = 50
BATCH_SIZE = 64

train(iterations=ITERATIONS, batch_size=BATCH_SIZE)
# Out:
# 2/2 [==============================] - 0s 66ms/step
# Iteration: 0
# d_loss_real: {'loss': 0.6912533044815063, 'accuracy': 0.53125}
# d_loss_gen: {'loss': 0.7201123237609863, 'accuracy': 0.203125}
# g_loss: [0.665270984172821, 0.640625]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 1
# d_loss_real: {'loss': 0.7050488591194153, 'accuracy': 0.78125}
# d_loss_gen: {'loss': 2.1259713172912598, 'accuracy': 0.328125}
# g_loss: [0.8263624310493469, 0.640625]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 2
# d_loss_real: {'loss': 0.7065774202346802, 'accuracy': 0.59375}
# d_loss_gen: {'loss': 2.4616641998291016, 'accuracy': 0.28125}
# g_loss: [0.6267357468605042, 0.734375]
# 2/2 [==============================] - 0s 28ms/step
# Iteration: 3
# d_loss_real: {'loss': 0.6820135116577148, 'accuracy': 0.703125}
# d_loss_gen: {'loss': 2.95015287399292, 'accuracy': 0.140625}
# g_loss: [0.33943718671798706, 0.90625]
# 2/2 [==============================] - 0s 30ms/step
# Iteration: 4
# d_loss_real: {'loss': 0.6603824496269226, 'accuracy': 0.71875}
# d_loss_gen: {'loss': 1.8981391191482544, 'accuracy': 0.171875}
# g_loss: [0.5333186388015747, 0.765625]
# 2/2 [==============================] - 0s 33ms/step
# Iteration: 5
# d_loss_real: {'loss': 0.6688692569732666, 'accuracy': 0.59375}
# d_loss_gen: {'loss': 0.7333697080612183, 'accuracy': 0.53125}
# g_loss: [1.711428165435791, 0.296875]
# 2/2 [==============================] - 0s 30ms/step
# Iteration: 6
# d_loss_real: {'loss': 0.7549811005592346, 'accuracy': 0.515625}
# d_loss_gen: {'loss': 0.6598520278930664, 'accuracy': 0.75}
# g_loss: [2.4697577953338623, 0.3125]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 7
# d_loss_real: {'loss': 0.6737890839576721, 'accuracy': 0.484375}
# d_loss_gen: {'loss': 0.6829057931900024, 'accuracy': 0.859375}
# g_loss: [4.09515380859375, 0.25]
# 2/2 [==============================] - 0s 28ms/step
# Iteration: 8
# d_loss_real: {'loss': 0.6297506093978882, 'accuracy': 0.5}
# d_loss_gen: {'loss': 0.9940685033798218, 'accuracy': 0.703125}
# g_loss: [3.686276435852051, 0.28125]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 9
# d_loss_real: {'loss': 0.6132348775863647, 'accuracy': 0.5625}
# d_loss_gen: {'loss': 1.2326056957244873, 'accuracy': 0.65625}
# g_loss: [3.028209924697876, 0.359375]
# 2/2 [==============================] - 0s 33ms/step
# Iteration: 10
# d_loss_real: {'loss': 0.8075124025344849, 'accuracy': 0.546875}
# d_loss_gen: {'loss': 2.1162314414978027, 'accuracy': 0.546875}
# g_loss: [2.7082886695861816, 0.390625]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 11
# d_loss_real: {'loss': 0.9696947932243347, 'accuracy': 0.390625}
# d_loss_gen: {'loss': 2.1482176780700684, 'accuracy': 0.5}
# g_loss: [1.601628303527832, 0.59375]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 12
# d_loss_real: {'loss': 0.7017048597335815, 'accuracy': 0.515625}
# d_loss_gen: {'loss': 2.835890293121338, 'accuracy': 0.3125}
# g_loss: [0.8740796446800232, 0.71875]
# 2/2 [==============================] - 0s 24ms/step
# Iteration: 13
# d_loss_real: {'loss': 0.7639890313148499, 'accuracy': 0.546875}
# d_loss_gen: {'loss': 2.1117396354675293, 'accuracy': 0.390625}
# g_loss: [0.9956780076026917, 0.609375]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 14
# d_loss_real: {'loss': 1.0275055170059204, 'accuracy': 0.515625}
# d_loss_gen: {'loss': 1.710001826286316, 'accuracy': 0.296875}
# g_loss: [1.25590980052948, 0.453125]
# 2/2 [==============================] - 0s 24ms/step
# Iteration: 15
# d_loss_real: {'loss': 0.8982053995132446, 'accuracy': 0.609375}
# d_loss_gen: {'loss': 0.8289880752563477, 'accuracy': 0.5625}
# g_loss: [1.4433797597885132, 0.328125]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 16
# d_loss_real: {'loss': 0.7768521904945374, 'accuracy': 0.546875}
# d_loss_gen: {'loss': 0.5131276845932007, 'accuracy': 0.6875}
# g_loss: [2.298264503479004, 0.3125]
# 2/2 [==============================] - 0s 29ms/step
# Iteration: 17
# d_loss_real: {'loss': 0.6657150983810425, 'accuracy': 0.65625}
# d_loss_gen: {'loss': 0.6475038528442383, 'accuracy': 0.75}
# g_loss: [3.7368216514587402, 0.25]
# 2/2 [==============================] - 0s 29ms/step
# Iteration: 18
# d_loss_real: {'loss': 0.6505892276763916, 'accuracy': 0.65625}
# d_loss_gen: {'loss': 1.4948148727416992, 'accuracy': 0.578125}
# g_loss: [3.7824442386627197, 0.328125]
# 2/2 [==============================] - 0s 22ms/step
# Iteration: 19
# d_loss_real: {'loss': 0.7568503022193909, 'accuracy': 0.671875}
# d_loss_gen: {'loss': 1.2442035675048828, 'accuracy': 0.625}
# g_loss: [2.8570685386657715, 0.296875]
# 2/2 [==============================] - 0s 30ms/step
# Iteration: 20
# d_loss_real: {'loss': 0.6952270269393921, 'accuracy': 0.703125}
# d_loss_gen: {'loss': 1.775977611541748, 'accuracy': 0.53125}
# g_loss: [2.547738552093506, 0.421875]
# 2/2 [==============================] - 0s 24ms/step
# Iteration: 21
# d_loss_real: {'loss': 0.6243060827255249, 'accuracy': 0.6875}
# d_loss_gen: {'loss': 1.4576740264892578, 'accuracy': 0.4375}
# g_loss: [1.807304859161377, 0.46875]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 22
# d_loss_real: {'loss': 0.6005767583847046, 'accuracy': 0.765625}
# d_loss_gen: {'loss': 1.5517847537994385, 'accuracy': 0.4375}
# g_loss: [2.7456321716308594, 0.28125]
# 2/2 [==============================] - 0s 21ms/step
# Iteration: 23
# d_loss_real: {'loss': 0.6181078553199768, 'accuracy': 0.640625}
# d_loss_gen: {'loss': 1.5339429378509521, 'accuracy': 0.5}
# g_loss: [3.706002712249756, 0.3125]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 24
# d_loss_real: {'loss': 0.5653148889541626, 'accuracy': 0.734375}
# d_loss_gen: {'loss': 1.2341080904006958, 'accuracy': 0.609375}
# g_loss: [3.860661029815674, 0.296875]
# 2/2 [==============================] - 0s 28ms/step
# Iteration: 25
# d_loss_real: {'loss': 0.6427628993988037, 'accuracy': 0.671875}
# d_loss_gen: {'loss': 1.2429518699645996, 'accuracy': 0.609375}
# g_loss: [5.455757141113281, 0.359375]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 26
# d_loss_real: {'loss': 0.7030587196350098, 'accuracy': 0.6875}
# d_loss_gen: {'loss': 2.1105799674987793, 'accuracy': 0.625}
# g_loss: [3.555077314376831, 0.390625]
# 2/2 [==============================] - 0s 29ms/step
# Iteration: 27
# d_loss_real: {'loss': 0.6771042346954346, 'accuracy': 0.65625}
# d_loss_gen: {'loss': 2.152679920196533, 'accuracy': 0.625}
# g_loss: [4.5356597900390625, 0.3125]
# 2/2 [==============================] - 0s 28ms/step
# Iteration: 28
# d_loss_real: {'loss': 0.6643053293228149, 'accuracy': 0.703125}
# d_loss_gen: {'loss': 2.910860776901245, 'accuracy': 0.484375}
# g_loss: [3.857203722000122, 0.390625]
# 2/2 [==============================] - 0s 21ms/step
# Iteration: 29
# d_loss_real: {'loss': 0.6987466812133789, 'accuracy': 0.59375}
# d_loss_gen: {'loss': 3.4176292419433594, 'accuracy': 0.4375}
# g_loss: [2.4682867527008057, 0.453125]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 30
# d_loss_real: {'loss': 0.7299845218658447, 'accuracy': 0.625}
# d_loss_gen: {'loss': 3.9153287410736084, 'accuracy': 0.359375}
# g_loss: [3.009700298309326, 0.46875]
# 2/2 [==============================] - 0s 23ms/step
# Iteration: 31
# d_loss_real: {'loss': 0.6524564027786255, 'accuracy': 0.734375}
# d_loss_gen: {'loss': 3.534386157989502, 'accuracy': 0.4375}
# g_loss: [3.007606029510498, 0.46875]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 32
# d_loss_real: {'loss': 0.762704074382782, 'accuracy': 0.640625}
# d_loss_gen: {'loss': 4.230948448181152, 'accuracy': 0.375}
# g_loss: [2.9270362854003906, 0.59375]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 33
# d_loss_real: {'loss': 0.759533166885376, 'accuracy': 0.578125}
# d_loss_gen: {'loss': 3.876728057861328, 'accuracy': 0.40625}
# g_loss: [2.5851125717163086, 0.53125]
# 2/2 [==============================] - 0s 29ms/step
# Iteration: 34
# d_loss_real: {'loss': 0.717798113822937, 'accuracy': 0.609375}
# d_loss_gen: {'loss': 2.9879355430603027, 'accuracy': 0.40625}
# g_loss: [3.4955525398254395, 0.40625]
# 2/2 [==============================] - 0s 24ms/step
# Iteration: 35
# d_loss_real: {'loss': 0.697023868560791, 'accuracy': 0.5625}
# d_loss_gen: {'loss': 3.4580507278442383, 'accuracy': 0.34375}
# g_loss: [2.9006571769714355, 0.40625]
# 2/2 [==============================] - 0s 24ms/step
# Iteration: 36
# d_loss_real: {'loss': 0.6882983446121216, 'accuracy': 0.609375}
# d_loss_gen: {'loss': 1.513430118560791, 'accuracy': 0.53125}
# g_loss: [5.944210529327393, 0.25]
# 2/2 [==============================] - 0s 28ms/step
# Iteration: 37
# d_loss_real: {'loss': 0.9021134376525879, 'accuracy': 0.53125}
# d_loss_gen: {'loss': 1.3503811359405518, 'accuracy': 0.65625}
# g_loss: [10.250423431396484, 0.203125]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 38
# d_loss_real: {'loss': 0.6537401676177979, 'accuracy': 0.40625}
# d_loss_gen: {'loss': 1.3590152263641357, 'accuracy': 0.75}
# g_loss: [9.364019393920898, 0.203125]
# 2/2 [==============================] - 0s 23ms/step
# Iteration: 39
# d_loss_real: {'loss': 0.6658112406730652, 'accuracy': 0.453125}
# d_loss_gen: {'loss': 0.5523422360420227, 'accuracy': 0.890625}
# g_loss: [12.641802787780762, 0.234375]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 40
# d_loss_real: {'loss': 0.7102938890457153, 'accuracy': 0.453125}
# d_loss_gen: {'loss': 1.91071617603302, 'accuracy': 0.703125}
# g_loss: [12.515785217285156, 0.171875]
# 2/2 [==============================] - 0s 23ms/step
# Iteration: 41
# d_loss_real: {'loss': 0.7642028331756592, 'accuracy': 0.625}
# d_loss_gen: {'loss': 2.367119550704956, 'accuracy': 0.734375}
# g_loss: [9.739215850830078, 0.28125]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 42
# d_loss_real: {'loss': 0.9460780620574951, 'accuracy': 0.46875}
# d_loss_gen: {'loss': 2.6376147270202637, 'accuracy': 0.59375}
# g_loss: [7.076816082000732, 0.28125]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 43
# d_loss_real: {'loss': 0.7534455060958862, 'accuracy': 0.578125}
# d_loss_gen: {'loss': 2.7426860332489014, 'accuracy': 0.625}
# g_loss: [10.793758392333984, 0.359375]
# 2/2 [==============================] - 0s 27ms/step
# Iteration: 44
# d_loss_real: {'loss': 0.7267979383468628, 'accuracy': 0.65625}
# d_loss_gen: {'loss': 3.464794874191284, 'accuracy': 0.65625}
# g_loss: [14.248201370239258, 0.3125]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 45
# d_loss_real: {'loss': 0.8772274255752563, 'accuracy': 0.5625}
# d_loss_gen: {'loss': 2.904498338699341, 'accuracy': 0.65625}
# g_loss: [20.102216720581055, 0.21875]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 46
# d_loss_real: {'loss': 0.7345067262649536, 'accuracy': 0.6875}
# d_loss_gen: {'loss': 5.251845359802246, 'accuracy': 0.640625}
# g_loss: [20.18596649169922, 0.28125]
# 2/2 [==============================] - 0s 29ms/step
# Iteration: 47
# d_loss_real: {'loss': 0.7564221620559692, 'accuracy': 0.609375}
# d_loss_gen: {'loss': 4.344369888305664, 'accuracy': 0.734375}
# g_loss: [14.094101905822754, 0.296875]
# 2/2 [==============================] - 0s 26ms/step
# Iteration: 48
# d_loss_real: {'loss': 0.6698439121246338, 'accuracy': 0.703125}
# d_loss_gen: {'loss': 2.3168044090270996, 'accuracy': 0.65625}
# g_loss: [10.019498825073242, 0.328125]
# 2/2 [==============================] - 0s 25ms/step
# Iteration: 49
# d_loss_real: {'loss': 0.8052270412445068, 'accuracy': 0.71875}
# d_loss_gen: {'loss': 2.162525177001953, 'accuracy': 0.65625}
# g_loss: [4.168612957000732, 0.375]

# %% [markdown]
# Generator-test

# %%
noise = np.random.normal(0,0.05, (1, AUDIO_COLS))
fake_audios = generator.predict(noise)
reshaped_fake_audio = np.reshape(fake_audios, AUDIO_COLS)

stftdata = librosa.stft(reshaped_fake_audio)
glAudio = librosa.griffinlim(stftdata)

#first sample
plt.figure(figsize=(12, 6))
plt.plot(reshaped_fake_audio[0:11025])

#first sample - griffin-lim
plt.figure(figsize=(12, 6))
plt.plot(glAudio[0:11025])
# Out:
# 1/1 [==============================] - 0s 112ms/step

# %%
sf.write("cc5g1d1gen.wav", reshaped_fake_audio, 11025)
sf.write("cc5g1d1gl.wav", glAudio, 11025)
