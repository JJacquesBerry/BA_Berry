# %% [markdown]
# - RNN-GAN - fourier-transformed audiodata - complex number values

# %%
import numpy as np
import tensorflow.keras as keras
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import soundfile as sf

# %% [markdown]
# Add path to util-functions

# %%
#add utils-folder as import-option
import sys
sys.path.append('D:/1. Studium/7. Semester/BA/Birdvoice/utils')

# %% [markdown]
# The Paths to the FT-databases

# %%
databasePathsParusMajor=['../../../../dataPreprocessing/databases/ft/parusMajor/ParusMajorSongFT1.csv', '../../../../dataPreprocessing/databases/ft/parusMajor/ParusMajorSongFT5.csv']
databasePathsTurdusMerula=['../../../../dataPreprocessing/databases/ft/turdusMerula/TurdusMerulaSongFT5.csv']
databasePathsCorvusCorone=['../../../../dataPreprocessing/databases/ft/corvusCorone/CorvusCoroneCallFT5.csv']

# %% [markdown]
# Load data from chosen path

# %%
readSampleCount = 500

#number of columns per dataset-sample for
ONE_SECOND = 22
FIVE_SECONDS = 108

#load and reshape data
x_train = pd.read_csv(databasePathsTurdusMerula[0], header=None, delimiter=',', index_col=None, nrows=readSampleCount).to_numpy()
x_train = np.reshape(x_train, [readSampleCount, 1025, FIVE_SECONDS])

#parse to complex128-datatype
x_train = x_train.astype('complex128')

_, AUDIO_ROWS, AUDIO_COLS = x_train.shape

# %% [markdown]
# Create optimizer

# %%
optimiser = keras.optimizers.Adamax(0.001, 0.9)

# %% [markdown]
# Create the discriminator

# %%
from utils.discriminatorsFT import *

# %%
discriminator = buildDiscriminator1(AUDIO_ROWS, AUDIO_COLS)
discriminator.compile(loss = "binary_crossentropy",
                      optimizer = optimiser,
                      metrics = "accuracy")

# %% [markdown]
# Create the generator and GAN

# %%
from utils.generatorsFT import *

# %%
generator = buildGenerator4(AUDIO_ROWS, AUDIO_COLS)
discriminator.trainable = False
gan = keras.models.Sequential( [generator, discriminator] )
gan.compile(loss="binary_crossentropy",
           optimizer = optimiser,
           metrics = "accuracy")

# %% [markdown]
# Run the training:

# %%
from utils.trainingFT import trainFT

# %%
ITERATIONS = 50
BATCH_SIZE = 1

print(discriminator.trainable)
discriminator.trainable = True
print(discriminator.trainable)

trainFT(iterations=ITERATIONS, batch_size=BATCH_SIZE, generator=generator, discriminator=discriminator, network=gan, data=x_train, columnCount=AUDIO_COLS)

print("Generator:")
generator.summary()
print("Discriminator:")
discriminator.summary()
print("GAN:")
gan.summary()
# Out:
# False
# False
# Iteration: 0
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7234252691268921, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6955274939537048, 'accuracy': 0.0039024390280246735}
# g_loss: [0.6909881234169006, 0.00585365854203701]
# Iteration: 1
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.694920003414154, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.6971595287322998, 'accuracy': 0.0009756097570061684}
# g_loss: [0.6897188425064087, 0.0019512195140123367]
# Iteration: 2
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6907228827476501, 'accuracy': 0.0019512195140123367}
# d_loss_gen: {'loss': 0.6999496221542358, 'accuracy': 0.0}
# g_loss: [0.6876499652862549, 0.0]
# Iteration: 3
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7268003225326538, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.7220817804336548, 'accuracy': 0.0}
# g_loss: [0.6775774955749512, 0.0]
# Iteration: 4
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7244603037834167, 'accuracy': 0.008780487813055515}
# d_loss_gen: {'loss': 0.7602083086967468, 'accuracy': 0.0}
# g_loss: [0.7299615740776062, 0.0]
# Iteration: 5
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6904799938201904, 'accuracy': 0.002926829271018505}
# d_loss_gen: {'loss': 0.6991147398948669, 'accuracy': 0.0}
# g_loss: [0.7747592329978943, 0.0]
# Iteration: 6
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.695909857749939, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6591346859931946, 'accuracy': 0.0}
# g_loss: [0.8081895112991333, 0.0]
# Iteration: 7
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.690295398235321, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.6417943835258484, 'accuracy': 0.0}
# g_loss: [0.837698221206665, 0.0]
# Iteration: 8
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6904587745666504, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6287041306495667, 'accuracy': 0.0}
# g_loss: [0.8565786480903625, 0.0]
# Iteration: 9
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6938220858573914, 'accuracy': 0.002926829271018505}
# d_loss_gen: {'loss': 0.6408699154853821, 'accuracy': 0.0}
# g_loss: [0.8406248092651367, 0.0]
# Iteration: 10
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6912581324577332, 'accuracy': 0.0039024390280246735}
# d_loss_gen: {'loss': 0.7150989174842834, 'accuracy': 0.0}
# g_loss: [0.7391356229782104, 0.0]
# Iteration: 11
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6922388672828674, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6934071779251099, 'accuracy': 0.0}
# g_loss: [0.6978136301040649, 0.0]
# Iteration: 12
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7700271010398865, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6950080394744873, 'accuracy': 0.0}
# g_loss: [0.693418562412262, 0.0]
# Iteration: 13
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6897770166397095, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.6978805661201477, 'accuracy': 0.0}
# g_loss: [0.6899529099464417, 0.0]
# Iteration: 14
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.69444739818573, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.7033365368843079, 'accuracy': 0.0}
# g_loss: [0.6864586472511292, 0.0]
# Iteration: 15
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6893919706344604, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.7185288667678833, 'accuracy': 0.0}
# g_loss: [0.6834389567375183, 0.0]
# Iteration: 16
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6893953680992126, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.7370414137840271, 'accuracy': 0.0}
# g_loss: [0.6788179874420166, 0.0]
# Iteration: 17
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6891904473304749, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.746268093585968, 'accuracy': 0.0}
# g_loss: [0.6725188493728638, 0.0]
# Iteration: 18
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6894248127937317, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.773054301738739, 'accuracy': 0.0}
# g_loss: [0.66233229637146, 0.0]
# Iteration: 19
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6923691630363464, 'accuracy': 0.0039024390280246735}
# d_loss_gen: {'loss': 0.819793164730072, 'accuracy': 0.0}
# g_loss: [0.6359295845031738, 0.0]
# Iteration: 20
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6904059052467346, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.8894878625869751, 'accuracy': 0.0}
# g_loss: [0.5910677313804626, 0.0]
# Iteration: 21
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7327462434768677, 'accuracy': 0.0039024390280246735}
# d_loss_gen: {'loss': 1.0573883056640625, 'accuracy': 0.0}
# g_loss: [0.5041068196296692, 0.0]
# Iteration: 22
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6984273791313171, 'accuracy': 0.013658536598086357}
# d_loss_gen: {'loss': 1.2296298742294312, 'accuracy': 0.0}
# g_loss: [0.4270559251308441, 0.0]
# Iteration: 23
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6904172897338867, 'accuracy': 0.0}
# d_loss_gen: {'loss': 1.2892827987670898, 'accuracy': 0.0}
# g_loss: [0.4060370624065399, 0.0]
# Iteration: 24
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6909390091896057, 'accuracy': 0.0}
# d_loss_gen: {'loss': 1.2613284587860107, 'accuracy': 0.0}
# g_loss: [0.4186200201511383, 0.0]
# Iteration: 25
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6957541108131409, 'accuracy': 0.0}
# d_loss_gen: {'loss': 1.168642520904541, 'accuracy': 0.0}
# g_loss: [0.45873716473579407, 0.0]
# Iteration: 26
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6914377808570862, 'accuracy': 0.0}
# d_loss_gen: {'loss': 1.0378971099853516, 'accuracy': 0.0}
# g_loss: [0.5268707275390625, 0.0]
# Iteration: 27
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6981280446052551, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.9076672196388245, 'accuracy': 0.0}
# g_loss: [0.6100233197212219, 0.0]
# Iteration: 28
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6920842528343201, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.7969363331794739, 'accuracy': 0.0}
# g_loss: [0.6980012059211731, 0.0]
# Iteration: 29
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6955415606498718, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.7011914849281311, 'accuracy': 0.0}
# g_loss: [0.7947936058044434, 0.0]
# Iteration: 30
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6955744028091431, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.6222204566001892, 'accuracy': 0.0}
# g_loss: [0.8955121040344238, 0.0]
# Iteration: 31
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.694743275642395, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.5613731741905212, 'accuracy': 0.0}
# g_loss: [0.9913922548294067, 0.0]
# Iteration: 32
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6925457715988159, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.512328565120697, 'accuracy': 0.0}
# g_loss: [1.0877784490585327, 0.0]
# Iteration: 33
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6921910047531128, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.464440256357193, 'accuracy': 0.0}
# g_loss: [1.1980735063552856, 0.0]
# Iteration: 34
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.7013179063796997, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.4109783172607422, 'accuracy': 0.0}
# g_loss: [1.340743899345398, 0.0]
# Iteration: 35
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6943572759628296, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.3516719341278076, 'accuracy': 0.0}
# g_loss: [1.5110893249511719, 0.0]
# Iteration: 36
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6933369636535645, 'accuracy': 0.0039024390280246735}
# d_loss_gen: {'loss': 0.2976062297821045, 'accuracy': 0.0}
# g_loss: [1.6918916702270508, 0.0]
# Iteration: 37
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6911637783050537, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.2487209290266037, 'accuracy': 0.0}
# g_loss: [1.8861161470413208, 0.0]
# Iteration: 38
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6922526359558105, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.20312270522117615, 'accuracy': 0.0}
# g_loss: [2.1016886234283447, 0.0]
# Iteration: 39
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6872782707214355, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.1630834937095642, 'accuracy': 0.0}
# g_loss: [2.3307104110717773, 0.0]
# Iteration: 40
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6857171654701233, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.12671194970607758, 'accuracy': 0.0}
# g_loss: [2.59859037399292, 0.0]
# Iteration: 41
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6833584904670715, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.09518548101186752, 'accuracy': 0.0}
# g_loss: [2.895522356033325, 0.0]
# Iteration: 42
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6809662580490112, 'accuracy': 0.0009756097570061684}
# d_loss_gen: {'loss': 0.07238611578941345, 'accuracy': 0.0}
# g_loss: [3.159071922302246, 0.0]
# Iteration: 43
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6875017285346985, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.058535195887088776, 'accuracy': 0.0}
# g_loss: [3.3471717834472656, 0.0]
# Iteration: 44
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6760164499282837, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.04724787548184395, 'accuracy': 0.0}
# g_loss: [3.5449059009552, 0.0]
# Iteration: 45
# 1/1 [==============================] - 6s 6s/step
# d_loss_real: {'loss': 0.6731757521629333, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.03805096074938774, 'accuracy': 0.0}
# g_loss: [3.7265877723693848, 0.0]
# Iteration: 46
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6752534508705139, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.03515242785215378, 'accuracy': 0.0}
# g_loss: [3.7970986366271973, 0.0]
# Iteration: 47
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6684099435806274, 'accuracy': 0.0}
# d_loss_gen: {'loss': 0.0351254865527153, 'accuracy': 0.0}
# g_loss: [3.749253988265991, 0.0]
# Iteration: 48
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6737077832221985, 'accuracy': 0.004878048785030842}
# d_loss_gen: {'loss': 0.04019086807966232, 'accuracy': 0.0}
# g_loss: [3.5819590091705322, 0.0]
# Iteration: 49
# 1/1 [==============================] - 5s 5s/step
# d_loss_real: {'loss': 0.6583954691886902, 'accuracy': 0.009756097570061684}
# d_loss_gen: {'loss': 0.0518222451210022, 'accuracy': 0.0}
# g_loss: [3.3141415119171143, 0.0]
# Generator:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1025, 256)         27904
#
#  dense_4 (Dense)             (None, 1025, 512)         131584
#
#  dense_5 (Dense)             (None, 1025, 1024)        525312
#
#  lstm (LSTM)                 (None, 1025, 2048)        25174016
#
#  dense_6 (Dense)             (None, 1025, 108)         221292
#
#  reshape (Reshape)           (None, 1025, 108)         0
#
# =================================================================
# Total params: 26,080,108
# Trainable params: 26,080,108
# Non-trainable params: 0
# _________________________________________________________________
# Discriminator:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1025, 512)         55808
#
#  dense_1 (Dense)             (None, 1025, 256)         131328
#
#  dense_2 (Dense)             (None, 1025, 108)         27756
#
# =================================================================
# Total params: 214,892
# Trainable params: 0
# Non-trainable params: 214,892
# _________________________________________________________________
# GAN:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 1025, 108)         26080108
#
#  sequential (Sequential)     (None, 1025, 108)         214892
#
# =================================================================
# Total params: 26,295,000
# Trainable params: 26,080,108
# Non-trainable params: 214,892
# _________________________________________________________________

# %% [markdown]
# Test of generator after training

# %%
noise = np.random.normal(0,0.1, (1, 1025, FIVE_SECONDS))  
fake_audios = generator.predict(noise)

glAudio = librosa.griffinlim(fake_audios[0])
istftAudio = librosa.istft(fake_audios[0])

plt.figure(figsize=(12, 6))
plt.plot(istftAudio*50)

plt.figure(figsize=(12, 6))
plt.plot(glAudio)
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
sf.write("tm5g4d1gen.wav", istftAudio, 11025)
sf.write("tm5g4d1gl.wav", glAudio, 11025)
