# %%
import librosa.display

# %% [markdown]
# Load Audiodata

# %% [markdown]
# - file-sr: 44100 (standard sr for audio-media)
#     - default-sr: 22050

# %%
audioPath = "../soundFiles/TroglodytesTroglodytes/WAV/TroglodytesTroglodytes0.wav"
#audioPath = "soundFiles/Test/test1.m4a"
    
audioData, sr = librosa.load(audioPath)
     
print(sr)
print(len(audioData))
# Out:
# 22050
# 479842

# %% [markdown]
# Examining Data

# %% [markdown]
# 1. audioData

# %% [markdown]
# 1.1 length
#
# The length is the number of samples, which is determined by the sample rate (sr) and the length of the audio in seconds (lis).
#
# - audioDataLength = sr * lis
#
# example: 2000 = 1000 * 2

# %%
print(len(audioData))
# Out:
# 1000

# %% [markdown]
# 1.2 data
#
# The data in audioSamples is a single list. Each element is either:
#
# - a float number
#
# or
#
# - a float number in scientific notation

# %%
#short
print(audioData)
# Out:
# [-2.85891467e-03 -4.23713913e-03 -1.39692880e-03  1.63200882e-03
#   4.39846423e-03  5.00396779e-03  5.02027757e-03  3.70502239e-03
#   8.86091730e-04 -8.17305292e-04 -2.03147670e-03 -1.80784345e-03
#   5.30520920e-04  1.25380117e-03  1.85697747e-03  3.89950466e-04
#  -2.24748091e-03 -2.03641527e-03 -4.00166539e-03 -4.43483470e-03
#  -2.43371329e-03 -9.58498917e-04  8.56774743e-04  2.28522997e-03
#   4.04357212e-03  2.91714608e-03  3.65684158e-03  5.34123648e-03
#   2.02951091e-03  6.85491657e-04 -7.65348610e-04 -3.02538299e-03
#  -4.85743815e-03 -6.55408436e-03 -5.26332343e-03 -4.56813071e-03
#  -3.00305756e-03  9.51641763e-04  3.94121697e-03  5.76777244e-03
#   6.13016030e-03  4.30184929e-03  2.49954057e-03  9.81269986e-04
#  -4.33713489e-04 -1.79441157e-03 -2.52997945e-03 -3.63801303e-03
#  -4.67082020e-03 -2.89933197e-03 -7.11000524e-04  2.40842160e-03
#   2.51714117e-03  1.33764104e-03  3.11431685e-03  1.44004275e-03
# ...

# %%
#long
for i in range(len(audioData)):
    print(audioData[i])
# Out:
# -0.0028589147
# -0.004237139
# -0.0013969288
# 0.0016320088
# 0.004398464
# 0.005003968
# 0.0050202776
# 0.0037050224
# 0.00088609173
# -0.0008173053
# -0.0020314767
# -0.0018078435
# 0.0005305209
# 0.0012538012
# 0.0018569775
# 0.00038995047
# -0.002247481
# -0.0020364153
# -0.0040016654
# -0.0044348347
# -0.0024337133
# -0.0009584989
# 0.00085677474
# 0.00228523
# 0.004043572
# 0.002917146
# 0.0036568416
# 0.0053412365
# 0.002029511
# 0.00068549166
# -0.0007653486
# -0.003025383
# -0.004857438
# -0.0065540844
# -0.0052633234
# -0.0045681307
# -0.0030030576
# 0.00095164176
# 0.003941217
# 0.0057677724
# 0.0061301603
# 0.0043018493
# 0.0024995406
# 0.00098127
# -0.0004337135
# -0.0017944116
# -0.0025299795
# -0.003638013
# -0.00467082
# -0.002899332
# -0.0007110005
# 0.0024084216
# 0.0025171412
# 0.001337641
# 0.0031143168
# 0.0014400427
# -0.0017867546
# -0.002571851
# -0.0025958202
# -0.0019827574
# -0.00012253414
# 0.0005319978
# 0.0007721179
# 0.00170568
# 0.002271631
# ...
